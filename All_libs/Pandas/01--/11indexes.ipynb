# %%
import pandas as pd
df = pd.read_csv(r'C:\dev\data-science\All_libs\Pandas\01--\assets\student_habits_performance.csv')

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.drop_duplicates(['sleep_hours', 'study_hours_per_day'], inplace=True)

# %%
ages_prob = df['age'].value_counts(normalize=True, sort=True, ascending=False) # Distribuição de probabilidade

# %%
ages_prob
# Out:
# age
# 20    0.155637
# 21    0.129902
# 17    0.129902
# 24    0.127451
# 23    0.122549
# 19    0.111520
# 18    0.111520
# 22    0.111520
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.bar(ages_prob.index, ages_prob.values)
# Out:
# <BarContainer object of 8 artists>

# %%
df.groupby(['age', 'gender'])['study_hours_per_day'].mean()
# Out:
# age  gender
# 17   Female    3.538298
#      Male      3.594545
#      Other     2.850000
# 18   Female    3.932000
#      Male      3.331579
#      Other     3.766667
# 19   Female    3.541304
#      Male      3.450000
#      Other     2.500000
# 20   Female    3.625000
#      Male      3.408333
#      Other     3.742857
# 21   Female    3.611538
#      Male      3.360417
#      Other     4.066667
# 22   Female    3.703922
#      Male      3.656410
#      Other     3.000000
# 23   Female    3.470455
#      Male      3.617647
#      Other     4.380000
# 24   Female    3.471429
#      Male      3.508929
#      Other     3.833333
# Name: study_hours_per_day, dtype: float64

# %%
df.pivot_table('study_hours_per_day', index='gender', columns='age', margins=True)
# Out:
# age           17        18        19        20        21        22        23  \
# gender
# Female  3.538298  3.932000  3.541304  3.625000  3.611538  3.703922  3.470455
# Male    3.594545  3.331579  3.450000  3.408333  3.360417  3.656410  3.617647
# Other   2.850000  3.766667  2.500000  3.742857  4.066667  3.000000  4.380000
# All     3.541509  3.675824  3.464835  3.529134  3.523585  3.675824  3.591000
#
# age           24       All
# gender
# Female  3.471429  3.618622
# Male    3.508929  3.492545
# Other   3.833333  3.677143
# All     3.512500  3.561029

# %%
df = df.set_index('parental_education_level')

# %%
df.loc[['Master', 'High School'], 'social_media_hours'].sort_index()
# Out:
# parental_education_level
# High School    4.5
# High School    1.3
# High School    2.9
# High School    2.9
# High School    4.2
#               ...
# Master         2.0
# Master         1.7
# Master         2.3
# Master         1.5
# Master         1.2
# Name: social_media_hours, Length: 455, dtype: float64

# %%
#df = df.reset_index()

# %%
#df = df.set_index(['diet_quality', 'parental_education_level']).sort_index(level=[0, 1])

# %%
df[df['exam_score'].between(70, 100)]
# Out:
#                          student_id  age  gender  study_hours_per_day  \
# parental_education_level
# High School                   S1001   20  Female                  6.9
# Master                        S1005   24    Male                  7.2
# Master                        S1006   21  Female                  5.6
# Bachelor                      S1007   21  Female                  4.3
# Bachelor                      S1008   23  Female                  4.4
# ...                             ...  ...     ...                  ...
# Bachelor                      S1988   18    Male                  3.3
# High School                   S1991   20    Male                  6.0
# Bachelor                      S1992   18    Male                  3.5
# High School                   S1993   20    Male                  3.8
# High School                   S1995   21  Female                  2.6
#
#                           social_media_hours  netflix_hours part_time_job  \
# parental_education_level
# High School                              2.8            2.3            No
# Master                                   1.3            0.0            No
# Master                                   1.5            1.4           Yes
# Bachelor                                 1.0            2.0           Yes
# Bachelor                                 2.2            1.7            No
# ...                                      ...            ...           ...
# Bachelor                                 2.4            1.2            No
# High School                              2.1            3.0            No
# Bachelor                                 0.0            1.9            No
# High School                              2.1            1.0            No
# High School                              0.5            1.6            No
#
#                           attendance_percentage  sleep_hours diet_quality  \
# parental_education_level
# High School                                97.3          4.6         Good
# Master                                     82.9          7.4         Fair
# Master                                     85.8          6.5         Good
# Bachelor                                   77.7          4.6         Fair
# Bachelor                                  100.0          7.1         Good
# ...                                         ...          ...          ...
# Bachelor                                   67.5          4.1         Fair
# High School                                86.7          5.1         Good
# Bachelor                                   96.8          6.4         Fair
# High School                                89.0          5.2         Good
# High School                                77.0          7.5         Fair
#
#                           exercise_frequency internet_quality  \
# parental_education_level
# High School                                6          Average
# Master                                     1          Average
# Master                                     2             Poor
# Bachelor                                   0          Average
# Bachelor                                   3             Good
# ...                                      ...              ...
# Bachelor                                   4          Average
# High School                                2             Good
# Bachelor                                   3             Poor
# High School                                1             Good
# High School                                2             Good
#
#                           mental_health_rating extracurricular_participation  \
# parental_education_level
# High School                                  8                            No
# Master                                       4                            No
# Master                                       4                            No
# Bachelor                                     8                            No
# Bachelor                                     1                            No
# ...                                        ...                           ...
# Bachelor                                     8                           Yes
# High School                                  3                            No
# Bachelor                                     3                            No
# High School                                  7                            No
# High School                                  6                           Yes
#
#                           exam_score
# parental_education_level
# High School                    100.0
# Master                         100.0
# Master                          89.8
# Bachelor                        72.6
# Bachelor                        78.9
# ...                              ...
# Bachelor                        72.5
# High School                     85.3
# Bachelor                        71.8
# High School                     70.9
# High School                     76.1
#
# [418 rows x 15 columns]

# %%
df.index.unique()
# Out:
# Index(['Master', 'High School', 'Bachelor', nan], dtype='object', name='parental_education_level')

# %%
df.mean(axis='index', numeric_only=True)
# Out:
# age                      20.506127
# study_hours_per_day       3.561029
# social_media_hours        2.511887
# netflix_hours             1.829412
# attendance_percentage    84.126593
# sleep_hours               6.468627
# exercise_frequency        3.078431
# mental_health_rating      5.399510
# exam_score               69.666544
# dtype: float64

# %%
df.groupby(level=0).mean(numeric_only=True)
# Out:
#                                 age  study_hours_per_day  social_media_hours  \
# parental_education_level
# Bachelor                  20.565068             3.511644            2.468836
# High School               20.334385             3.559306            2.554574
# Master                    20.536232             3.639130            2.520290
#
#                           netflix_hours  attendance_percentage  sleep_hours  \
# parental_education_level
# Bachelor                       1.856164              84.198973     6.525342
# High School                    1.847634              84.053628     6.441009
# Master                         1.805797              82.818116     6.424638
#
#                           exercise_frequency  mental_health_rating  exam_score
# parental_education_level
# Bachelor                            3.160959              5.746575   70.502055
# High School                         3.113565              5.356467   69.405994
# Master                              2.826087              4.811594   68.284058

# %%
import matplotlib.pyplot as plt

df.pivot_table(index='gender', columns='mental_health_rating', values='exam_score', aggfunc='median').plot.bar()
plt.title('KKKKKKK')
# Out:
# Text(0.5, 1.0, 'KKKKKKK')

# %%
df.groupby(['gender', 'mental_health_rating'])['exam_score'].mean().plot.bar()
# Out:
# <Axes: xlabel='gender,mental_health_rating'>

# %%
df.mean(axis=1, numeric_only=True)
# Out:
# parental_education_level
# Master         20.944444
# High School    27.544444
# High School    18.433333
# Master         15.655556
# Master         21.677778
#                  ...
# High School    17.044444
# High School    21.588889
# High School    21.000000
# Bachelor       19.300000
# Bachelor       23.655556
# Length: 816, dtype: float64
