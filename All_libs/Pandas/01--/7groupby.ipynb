# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\dev\data-science\Projects\04-Titanic\assets\train.csv')

# %%
for group, frame in df.groupby('Sex'):  # Analisando todas as colunas ao mesmo tempo
    print(frame['Sex'][:3])
# Out:
# 1    female
# 2    female
# 3    female
# Name: Sex, dtype: object
# 0    male
# 4    male
# 5    male
# Name: Sex, dtype: object

# %%
g = df.groupby(['Sex', 'Pclass'])
g.groups.keys()
# Out:
# dict_keys([('female', 1), ('female', 2), ('female', 3), ('male', 1), ('male', 2), ('male', 3)])

# %%
import numpy as np

results = {}
combinations = df.groupby(['Pclass', 'Sex']).groups.keys()

for combo in combinations:
    results[combo] = []

for c in range(1, 50):
    filtered_df = df[df['Age'] > c]

    if not filtered_df.empty:
        grouped = filtered_df.groupby(['Pclass', 'Sex'])['Survived'].mean()
        for combo in combinations:
            results[combo].append(grouped.get(combo, np.nan))
    else:
        for combo in combinations:
            results[combo].append(np.nan)

# %%
ages = list(range(1, 50))

plt.title('Taxa de Sobrevivência por Idade, Classe e Sexo')
plt.xlabel('Idade mínima (c)')
plt.ylabel('Taxa de Sobrevivência')

for combo, survivals in results.items():
    pclass, sex = combo
    label = f'Pclass {pclass} - {sex}'
    plt.plot(ages, survivals, label=label)

plt.legend(title='Grupo', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
df.groupby(['Sex', 'Pclass'])['Age'].max()
# Out:
# Sex     Pclass
# female  1         63.0
#         2         57.0
#         3         63.0
# male    1         80.0
#         2         70.0
#         3         74.0
# Name: Age, dtype: float64

# %%
g = df.groupby(['Sex', 'Pclass']).filter(lambda x: x['Survived'].sum() > 50)
g = g.groupby(['Sex', 'Pclass'])['Survived'].agg(['mean', 'sum', 'count'])
g['deaths'] = g['count'] - g['sum']
g
# Out:
#                    mean  sum  count  deaths
# Sex    Pclass
# female 1       0.968085   91     94       3
#        2       0.921053   70     76       6
#        3       0.500000   72    144      72

# %%
df.groupby(['Pclass', 'Sex'])['Age'].transform('mean')  # Criar novas colunas apartir de agrupamentos
# Out:
# 0      26.507589
# 1      34.611765
# 2      21.750000
# 3      34.611765
# 4      26.507589
#          ...
# 886    30.740707
# 887    34.611765
# 888    21.750000
# 889    41.281386
# 890    26.507589
# Name: Age, Length: 891, dtype: float64

# %%
"""df.reset_index(inplace=True)
df.set_index('Age', inplace=True)

def classe(index):
    if index < 18:
        return 'new'
    elif 18 < index <= 50:
        return 'adult' 
    else:
        return 'older'
    
df.groupby(classe)[['Survived', 'Fare']].agg({'Survived':'count', 'Fare': ('mean', 'median')})"""
# Out:
# "df.reset_index(inplace=True)\ndf.set_index('Age', inplace=True)\n\ndef classe(index):\n    if index < 18:\n        return 'new'\n    elif 18 < index <= 50:\n        return 'adult' \n    else:\n        return 'older'\n\ndf.groupby(classe)[['Survived', 'Fare']].agg({'Survived':'count', 'Fare': ('mean', 'median')})"

# %%
df['age_category'] = pd.cut(df['Age'], bins=[0, 18, 50, 80], labels=['new', 'adult', 'older'])
# labels entram como os intervalos.

# %%
import matplotlib.pyplot as plt

df_grouped = df.groupby(['Sex', 'age_category'])['Pclass'].value_counts().unstack().fillna(0)

df_grouped.plot(kind='bar', width=0.8, figsize=(8,5))

plt.title('Distribuição de Pclass por Sex e Age Category')
plt.xlabel('Sex e Age Category')
plt.ylabel('Contagem de Pclass')
plt.xticks(rotation=45)
plt.legend(title='Pclass', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_27180\1414943736.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df.groupby(['Sex', 'age_category'])['Pclass'].value_counts().unstack().fillna(0)

# %%
df_grouped
# Out:
# Pclass                1   2    3
# Sex    age_category
# female new           11  14   43
#        adult         61  57   58
#        older         13   3    1
# male   new            5  15   51
#        adult         70  72  193
#        older         26  12    9

# %%
df['Name2'] = np.nan

# %%
df.filter(like="Name")
# Out:
#                                                   Name  Name2
# 0                              Braund, Mr. Owen Harris    NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    NaN
# 2                               Heikkinen, Miss. Laina    NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    NaN
# 4                             Allen, Mr. William Henry    NaN
# ..                                                 ...    ...
# 886                              Montvila, Rev. Juozas    NaN
# 887                       Graham, Miss. Margaret Edith    NaN
# 888           Johnston, Miss. Catherine Helen "Carrie"    NaN
# 889                              Behr, Mr. Karl Howell    NaN
# 890                                Dooley, Mr. Patrick    NaN
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked age_category  Name2
# 0        0         A/5 21171   7.2500   NaN        S        adult    NaN
# 1        0          PC 17599  71.2833   C85        C        adult    NaN
# 2        0  STON/O2. 3101282   7.9250   NaN        S        adult    NaN
# 3        0            113803  53.1000  C123        S        adult    NaN
# 4        0            373450   8.0500   NaN        S        adult    NaN
# ..     ...               ...      ...   ...      ...          ...    ...
# 886      0            211536  13.0000   NaN        S        adult    NaN
# 887      0            112053  30.0000   B42        S        adult    NaN
# 888      2        W./C. 6607  23.4500   NaN        S          NaN    NaN
# 889      0            111369  30.0000  C148        C        adult    NaN
# 890      0            370376   7.7500   NaN        Q        adult    NaN
#
# [891 rows x 14 columns]

# %%
g = df.groupby(['Sex', 'age_category']).filter(lambda x: x['Survived'].sum() > 50)
g['Pclass'].agg([lambda col: col.quantile(0.75), 'mean'])
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_27180\2525417811.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g = df.groupby(['Sex', 'age_category']).filter(lambda x: x['Survived'].sum() > 50)
# <lambda>    3.000000
# mean        2.234834
# Name: Pclass, dtype: float64

# %%
df['Age'].cumsum() # cumulativo
# Out:
# 0         22.00
# 1         60.00
# 2         86.00
# 3        121.00
# 4        156.00
#          ...
# 886    21128.17
# 887    21147.17
# 888         NaN
# 889    21173.17
# 890    21205.17
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].cummax()
# Out:
# 0      22.0
# 1      38.0
# 2      38.0
# 3      38.0
# 4      38.0
#        ...
# 886    80.0
# 887    80.0
# 888     NaN
# 889    80.0
# 890    80.0
# Name: Age, Length: 891, dtype: float64

# %%
pivot = df.pivot_table('Survived', index='Sex', columns='Pclass').plot.bar()
